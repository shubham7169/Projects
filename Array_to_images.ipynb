# %% [markdown]
# ##### import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import matplotlib.pyplot as plt
# from PIL import Image, ImageDraw

# %%
import csv

# %%
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')
train.head()

labels=train['label']


train.drop('label', axis = 1, inplace = True)
train.head()


images = train.values
images = np.array([np.reshape(i, (28, 28)) for i in images])
images.shape

array = images.astype(np.uint8)
for i, image in enumerate(array):
        Image.fromarray(image).save(f"{i}.jpg")

# %%
test = pd.read_csv('sign_mnist_test.csv')
test.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     151  ...       138       148       127        89        82        96
# 1     136  ...        47       104       194       183       186       184
# 2     147  ...        68       166       242       227       230       227
# 3     210  ...       154       248       247       248       253       236
# 4     203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
labels=test['label']

# %%
test.drop('label', axis = 1, inplace = True)
test.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     149     149     150     150     150     151     151     150     151
# 1     126     128     131     132     133     134     135     135     136
# 2      85      88      92      96     105     123     135     143     147
# 3     203     205     207     206     207     209     210     209     210
# 4     188     191     193     195     199     201     202     203     203
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      152  ...       138       148       127        89        82        96
# 1      138  ...        47       104       194       183       186       184
# 2      152  ...        68       166       242       227       230       227
# 3      209  ...       154       248       247       248       253       236
# 4      203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# ...

# %%
images = test.values
images = np.array([np.reshape(i, (28, 28)) for i in images])
images.shape

array = images.astype(np.uint8)
for i, image in enumerate(array):
        Image.fromarray(image).save(f"image{i}.jpg")

# %%
q=[]
for i in range(len(labels)):
    u='image'+str(i)+'.jpg'
    q.append(u)

# %%
# Out:
# ['image0.jpg',
#  'image1.jpg',
#  'image2.jpg',
#  'image3.jpg',
#  'image4.jpg',
#  'image5.jpg',
#  'image6.jpg',
#  'image7.jpg',
#  'image8.jpg',
#  'image9.jpg',
#  'image10.jpg',
#  'image11.jpg',
#  'image12.jpg',
#  'image13.jpg',
#  'image14.jpg',
#  'image15.jpg',
#  'image16.jpg',
#  'image17.jpg',
#  'image18.jpg',
#  'image19.jpg',
#  'image20.jpg',
#  'image21.jpg',
#  'image22.jpg',
#  'image23.jpg',
#  'image24.jpg',
#  'image25.jpg',
#  'image26.jpg',
#  'image27.jpg',
#  'image28.jpg',
#  'image29.jpg',
#  'image30.jpg',
#  'image31.jpg',
#  'image32.jpg',
#  'image33.jpg',
#  'image34.jpg',
#  'image35.jpg',
#  'image36.jpg',
#  'image37.jpg',
#  'image38.jpg',
#  'image39.jpg',
#  'image40.jpg',
#  'image41.jpg',
#  'image42.jpg',
#  'image43.jpg',
#  'image44.jpg',
#  'image45.jpg',
#  'image46.jpg',
#  'image47.jpg',
#  'image48.jpg',
#  'image49.jpg',
#  'image50.jpg',
#  'image51.jpg',
#  'image52.jpg',
#  'image53.jpg',
#  'image54.jpg',
#  'image55.jpg',
# ...

# %%
test_label = pd.DataFrame(q, columns = ['id'])

# %%
label = pd.DataFrame(labels, columns = ['label'])

# %%
test_label['label']=label['label']

# %%
test_label.tail()
# Out:
#                  id  label
# 7167  image7167.jpg      1
# 7168  image7168.jpg     12
# 7169  image7169.jpg      2
# 7170  image7170.jpg      4
# 7171  image7171.jpg      2

# %%
import n2w

# %%
r=[]
v=[]
for i in range(len(labels)):
    r=n2w.convert(labels[i])
    v.append(r)

# %%
v
# Out:
# ['six',
#  'five',
#  'ten',
#  'zero',
#  'three',
#  'twenty one',
#  'ten',
#  'fourteen',
#  'three',
#  'seven',
#  'eight',
#  'eight',
#  'twenty one',
#  'twelve',
#  'seven',
#  'four',
#  'twenty two',
#  'zero',
#  'seven',
#  'seven',
#  'two',
#  'zero',
#  'twenty one',
#  'four',
#  'ten',
#  'fifteen',
#  'two',
#  'fifteen',
#  'seven',
#  'one',
#  'seven',
#  'eight',
#  'thirteen',
#  'nineteen',
#  'three',
#  'twenty one',
#  'thirteen',
#  'three',
#  'eighteen',
#  'fourteen',
#  'fifteen',
#  'twenty three',
#  'eight',
#  'fifteen',
#  'fourteen',
#  'five',
#  'seventeen',
#  'four',
#  'nineteen',
#  'thirteen',
#  'twenty',
#  'twenty two',
#  'twenty',
#  'five',
#  'sixteen',
#  'sixteen',
#  'twenty one',
#  'four',
#  'seven',
#  'twenty two',
#  'ten',
#  'thirteen',
#  'eleven',
#  'twenty two',
#  'two',
#  'ten',
#  'one',
#  'four',
#  'eighteen',
#  'four',
#  'twenty',
#  'six',
#  'fifteen',
#  'four',
#  'three',
#  'twenty',
#  'fifteen',
# ...

# %%
k=[]
for i in v:
    h=i.replace(" ","_")
    k.append(h)

# %%
k
# Out:
# ['six',
#  'five',
#  'ten',
#  'zero',
#  'three',
#  'twenty_one',
#  'ten',
#  'fourteen',
#  'three',
#  'seven',
#  'eight',
#  'eight',
#  'twenty_one',
#  'twelve',
#  'seven',
#  'four',
#  'twenty_two',
#  'zero',
#  'seven',
#  'seven',
#  'two',
#  'zero',
#  'twenty_one',
#  'four',
#  'ten',
#  'fifteen',
#  'two',
#  'fifteen',
#  'seven',
#  'one',
#  'seven',
#  'eight',
#  'thirteen',
#  'nineteen',
#  'three',
#  'twenty_one',
#  'thirteen',
#  'three',
#  'eighteen',
#  'fourteen',
#  'fifteen',
#  'twenty_three',
#  'eight',
#  'fifteen',
#  'fourteen',
#  'five',
#  'seventeen',
#  'four',
#  'nineteen',
#  'thirteen',
#  'twenty',
#  'twenty_two',
#  'twenty',
#  'five',
#  'sixteen',
#  'sixteen',
#  'twenty_one',
#  'four',
#  'seven',
#  'twenty_two',
#  'ten',
#  'thirteen',
#  'eleven',
#  'twenty_two',
#  'two',
#  'ten',
#  'one',
#  'four',
#  'eighteen',
#  'four',
#  'twenty',
#  'six',
#  'fifteen',
#  'four',
#  'three',
#  'twenty',
#  'fifteen',
# ...

# %%
k=pd.DataFrame(k, columns = ['labels'])

# %%
test_label['labels']=k['labels']

# %%
test_label.tail()
# Out:
#                  id  labels
# 7167  image7167.jpg     one
# 7168  image7168.jpg  twelve
# 7169  image7169.jpg     two
# 7170  image7170.jpg    four
# 7171  image7171.jpg     two

# %%
test_label.to_csv('test_label.csv',index=False)

# %%
labels.to_csv('label.csv')
# Out:
# C:\Users\SHUBHAM\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
train = pd.read_csv('sign_mnist_train.csv')
test = pd.read_csv('sign_mnist_test.csv')
train.head()

labels=train['label']

# %%
labels.head()
# Out:
# 0     3
# 1     6
# 2     2
# 3     2
# 4    13
# Name: label, dtype: int64

# %%
label=pd.read_csv('label.csv')

# %%
label.head()
l=label['id']
l=l.astype('str')

# %%
for i in range(len(l)):
    l[i]=l[i]+'.jpg'

# %%
for i in range(len(l)):
    print(l[i])
# Out:
# 0.jpg
# 1.jpg
# 2.jpg
# 3.jpg
# 4.jpg
# 5.jpg
# 6.jpg
# 7.jpg
# 8.jpg
# 9.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 30.jpg
# 31.jpg
# 32.jpg
# 33.jpg
# 34.jpg
# 35.jpg
# 36.jpg
# 37.jpg
# 38.jpg
# 39.jpg
# 40.jpg
# 41.jpg
# 42.jpg
# 43.jpg
# 44.jpg
# 45.jpg
# 46.jpg
# 47.jpg
# 48.jpg
# 49.jpg
# 50.jpg
# 51.jpg
# 52.jpg
# 53.jpg
# 54.jpg
# 55.jpg
# 56.jpg
# 57.jpg
# 58.jpg
# 59.jpg
# 60.jpg
# 61.jpg
# 62.jpg
# 63.jpg
# 64.jpg
# 65.jpg
# 66.jpg
# 67.jpg
# 68.jpg
# 69.jpg
# 70.jpg
# 71.jpg
# 72.jpg
# 73.jpg
# 74.jpg
# 75.jpg
# 76.jpg
# 77.jpg
# 78.jpg
# 79.jpg
# 80.jpg
# 81.jpg
# 82.jpg
# 83.jpg
# 84.jpg
# 85.jpg
# 86.jpg
# 87.jpg
# 88.jpg
# 89.jpg
# 90.jpg
# 91.jpg
# 92.jpg
# 93.jpg
# 94.jpg
# 95.jpg
# 96.jpg
# 97.jpg
# 98.jpg
# 99.jpg
# 100.jpg
# 101.jpg
# 102.jpg
# 103.jpg
# 104.jpg
# 105.jpg
# 106.jpg
# 107.jpg
# 108.jpg
# 109.jpg
# 110.jpg
# ...

# %%
df = pd.DataFrame(l, columns = ['id'])

# %%
df['label']=label['label']

# %%
df.head()
# Out:
#       id  label
# 0  0.jpg    3.0
# 1  1.jpg    6.0
# 2  2.jpg    2.0
# 3  3.jpg    2.0
# 4  4.jpg   13.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27456 entries, 0 to label
# Data columns (total 2 columns):
# id       27456 non-null object
# label    27455 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 643.5+ KB

# %%
df.to_csv('labels.csv')

# %%
d=pd.read_csv('labels.csv')

# %%
df=df.astype('str')

# %%
df.to_csv('labels.csv')

# %%
s=df['label']

# %%
s = pd.DataFrame(s, columns = ['label'])

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Data columns (total 2 columns):
# label    27455 non-null float64
# id       27455 non-null object
# dtypes: float64(1), object(1)
# memory usage: 429.1+ KB

# %%
s['id']=df['id']

# %%
s.to_csv('labels.csv',quoting=csv.QUOTE_NONNUMERIC,index=False)

# %%
s=df['label']

# %%
s=pd.DataFrame(s, columns = ['label'])

# %%
for i in range(len(s)-1):
    s[i]=str(s[i])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-c7da360baa61> in <module>
#       1 for i in range(len(s)-1):
# ----> 2     s[i]=str(s[i])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
s['id']=df['id']

# %%
s=s[:27455]

# %%
s.tail()
# Out:
#       label         id
# 27450  13.0  27450.jpg
# 27451  23.0  27451.jpg
# 27452  18.0  27452.jpg
# 27453  17.0  27453.jpg
# 27454  23.0  27454.jpg

# %%
s['label'][27454]='23.0'

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27455 entries, 0 to 27454
# Data columns (total 2 columns):
# label    27455 non-null object
# id       27455 non-null object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
s.dtypes.to_frame('types').to_csv('types.csv')
s.to_csv('file.csv', index=False)

# %%
df_types = pd.read_csv('types.csv')['types']
df = pd.read_csv('file.csv', dtype=df_types.to_dict())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Data columns (total 2 columns):
# label    27455 non-null object
# id       27455 non-null object
# dtypes: object(2)
# memory usage: 429.1+ KB

# %%
df.tail()
# Out:
#       label         id
# 27450  13.0  27450.jpg
# 27451  23.0  27451.jpg
# 27452  18.0  27452.jpg
# 27453  17.0  27453.jpg
# 27454  23.0  27454.jpg

# %%
df.to_csv('label.csv',quoting=csv.QUOTE_NONNUMERIC,index=False)

# %%
df_types = pd.read_csv('label.csv')
df_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Data columns (total 2 columns):
# label    27455 non-null float64
# id       27455 non-null object
# dtypes: float64(1), object(1)
# memory usage: 429.1+ KB

# %%
a=pd.read_csv('label.csv')

# %%
a.head()

# %%
a['sd']='a'

# %%
b=a['label']

# %%
import string

# %%
r=[]
v=[]
for i in range(len(b)):
    r=n2w.convert(b[i])
    v.append(r)

# %%
import n2w

# %%
v=pd.DataFrame(v, columns = ['labels'])

# %%
v['id']=a['id']

# %%
v.to_csv('labels.csv',index=False)

# %%
f=pd.read_csv('labels.csv')

# %%
x=f['labels']

# %%
g="i am hero"
g.replace(" ","_")
# Out:
# 'i_am_hero'

# %%
k=[]
for i in x:
    h=i.replace(" ","_")
    k.append(h)

# %%
k
# Out:
# ['three',
#  'six',
#  'two',
#  'two',
#  'thirteen',
#  'sixteen',
#  'eight',
#  'twenty_two',
#  'three',
#  'three',
#  'eighteen',
#  'ten',
#  'sixteen',
#  'twenty_two',
#  'twenty',
#  'sixteen',
#  'seventeen',
#  'thirteen',
#  'thirteen',
#  'nineteen',
#  'eighteen',
#  'twenty_one',
#  'sixteen',
#  'twenty_three',
#  'three',
#  'twenty_three',
#  'twenty_four',
#  'eighteen',
#  'twenty_two',
#  'one',
#  'one',
#  'twelve',
#  'two',
#  'six',
#  'two',
#  'twelve',
#  'twenty_three',
#  'two',
#  'three',
#  'thirteen',
#  'eleven',
#  'fifteen',
#  'twenty',
#  'two',
#  'four',
#  'ten',
#  'zero',
#  'nineteen',
#  'five',
#  'seven',
#  'zero',
#  'eleven',
#  'six',
#  'twenty_one',
#  'eighteen',
#  'nineteen',
#  'twenty_one',
#  'seven',
#  'zero',
#  'zero',
#  'four',
#  'fourteen',
#  'fifteen',
#  'ten',
#  'five',
#  'nineteen',
#  'two',
#  'thirteen',
#  'seven',
#  'sixteen',
#  'twelve',
#  'eight',
#  'fifteen',
#  'eleven',
#  'twenty_one',
# ...

# %%
k=pd.DataFrame(k, columns = ['labels'])

# %%
k['id']=f['id']

# %%
k.head(10)
# Out:
#        labels     id
# 0       three  0.jpg
# 1         six  1.jpg
# 2         two  2.jpg
# 3         two  3.jpg
# 4    thirteen  4.jpg
# 5     sixteen  5.jpg
# 6       eight  6.jpg
# 7  twenty_two  7.jpg
# 8       three  8.jpg
# 9       three  9.jpg

# %%
k.to_csv('label_data.csv',index=False)

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'nic.goi.aarogyasetu',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'nic.goi.aarogyasetu',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
print(result)
# Out:
# [{'userName': 'Siddhartha mudgal', 'userImage': 'https://lh3.googleusercontent.com/-DaHuBuquFfw/AAAAAAAAAAI/AAAAAAAAAAA/AAKWJJP89HrF-1nk1AKcUBY2hDuJ-Uy86A/photo.jpg', 'content': 'This is an extremely good effort, I just want to suggest that, advertise these type of apps as much as you can, so that most of the person have it installed, only then the efforts will be fruit full. I also want to add that some smartphone makers use aggressive background app killer, so I have noticed that the app is not able to operate in background, if mobile is on standby mode( when screen is off) after 20-30 minutes, If any solution you can make it will be more beneficial.', 'score': 5, 'thumbsUpCount': 855, 'reviewCreatedVersion': '1.0.4', 'at': datetime.datetime(2020, 4, 13, 7, 53, 35), 'replyContent': "Hi! We are glad that you like our app. We'd very much appreciate if you have any recommendations/suggestions for us. Do share it with your friends so that more number of citizens can register.", 'replie
# ...

# %%
review=[]
for i in range(len(result)):
    r=result[i]['content']
    review.append(r)

# %%
review
# Out:
# ['This is an extremely good effort, I just want to suggest that, advertise these type of apps as much as you can, so that most of the person have it installed, only then the efforts will be fruit full. I also want to add that some smartphone makers use aggressive background app killer, so I have noticed that the app is not able to operate in background, if mobile is on standby mode( when screen is off) after 20-30 minutes, If any solution you can make it will be more beneficial.',
#  'The App is good. These are desperate times and this calls for it so below are my requirements. Force push this app in all online smartphones/no uninstall option, travel history to be integrated via registered mobile number. Track non smartphones through sim and edge data. Track all app users all the time like how many times one has moved out (threshold 50 metres)even for groceries/ display history in home screen and authorities dashboard.',
# ...
